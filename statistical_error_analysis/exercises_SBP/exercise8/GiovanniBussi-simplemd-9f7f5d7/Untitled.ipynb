# %%
# %%bash # this command line is not necessary
# cat xyz/in
# Out:
# inputfile xyz/crystal10.xyz
# outputfile xyz/output.xyz
# temperature 0.1
# tstep 0.01
# friction 0.0
# forcecutoff 2.5
# listcutoff  3.0
# nstep 8000
# nconfig 10 xyz/trajectory.xyz
# nstat   10 xyz/energies.dat

# %%
v=2
w=v+1
print(w)
# Out:
# 3

# %%
cat xyz/in
# Out:
# inputfile xyz/crystal10.xyz
# outputfile xyz/output.xyz
# temperature 0.1
# tstep 0.01
# friction 0.0
# forcecutoff 2.5
# listcutoff  3.0
# nstep 8000
# nconfig 10 xyz/trajectory.xyz
# nstat   10 xyz/energies.dat

# %%
# %%bash
# python3 python/simplemd.py < xyz/in
# Out:
# Neighbour list recomputed at step  0
# List size:  4000
# Neighbour list recomputed at step  107
# List size:  4000
# Neighbour list recomputed at step  184
# List size:  4000
# Neighbour list recomputed at step  230
# List size:  4000
# Neighbour list recomputed at step  279
# List size:  4000
# Neighbour list recomputed at step  392
# List size:  4000
# Neighbour list recomputed at step  460
# List size:  4000
# Neighbour list recomputed at step  501
# List size:  4000
# Neighbour list recomputed at step  607
# List size:  4000
# Neighbour list recomputed at step  689
# List size:  4000
# Neighbour list recomputed at step  720
# List size:  4000
# Neighbour list recomputed at step  778
# List size:  4000
# Neighbour list recomputed at step  859
# List size:  4000
# Neighbour list recomputed at step  925
# List size:  4000
# Neighbour list recomputed at step  1015
# List size:  4000
# Neighbour list recomputed at step  1124
# List size:  4000
# Neighbour list recomputed at step  1222
# List size:  4000
# Neighbour list recomputed at step  1308
# List size:  4000
# Neighbour list recomputed at step  1415
# List size:  4000
# Neighbour list recomputed at step  1526
# List size:  4000
# Neighbour list recomputed at step  1572
# List size:  4000
# Neighbour list recomputed at step  1635
# List size:  4000
# Neighbour list recomputed at step  1723
# List size:  4000
# Neighbour list recomputed at step  1783
# List size:  4000
# Neighbour list recomputed at step  1818
# List size:  4000
# Neighbour list recomputed at step  1852
# List size:  4000
# Neighbour list recomputed at step  1954
# List size:  4000
# Neighbour list recomputed at step  2015
# List size:  4000
# Neighbour list recomputed at step  2069
# List size:  4000
# Neighbour list recomputed at step  2099
# List size:  4000
# Neighbour list recomputed at step  2197
# List size:  4000
# Neighbour list recomputed at step  2297
# List size:  4000
# Neighbour list recomputed at step  2335
# List size:  4000
# Neighbour list recomputed at step  2363
# List size:  4000
# Neighbour list recomputed at step  2420
# List size:  4000
# Neighbour list recomputed at step  2453
# List size:  4000
# Neighbour list recomputed at step  2502
# List size:  4000
# Neighbour list recomputed at step  2559
# List size:  4000
# Neighbour list recomputed at step  2658
# List size:  4000
# Neighbour list recomputed at step  2721
# List size:  4000
# Neighbour list recomputed at step  2820
# List size:  4000
# Neighbour list recomputed at step  2904
# List size:  4000
# Neighbour list recomputed at step  2978
# List size:  4000
# Neighbour list recomputed at step  3025
# List size:  4000
# Neighbour list recomputed at step  3091
# List size:  4000
# Neighbour list recomputed at step  3137
# List size:  4000
# Neighbour list recomputed at step  3190
# List size:  4000
# Neighbour list recomputed at step  3233
# List size:  4000
# Neighbour list recomputed at step  3328
# List size:  4000
# Neighbour list recomputed at step  3370
# List size:  4000
# Neighbour list recomputed at step  3427
# List size:  4000
# Neighbour list recomputed at step  3483
# List size:  4000
# Neighbour list recomputed at step  3520
# List size:  4000
# Neighbour list recomputed at step  3584
# List size:  4000
# Neighbour list recomputed at step  3671
# List size:  4000
# Neighbour list recomputed at step  3745
# List size:  4000
# Neighbour list recomputed at step  3851
# List size:  4000
# Neighbour list recomputed at step  3945
# List size:  4000
# Neighbour list recomputed at step  4027
# List size:  4000
# Neighbour list recomputed at step  4110
# List size:  4000
# Neighbour list recomputed at step  4135
# List size:  4000
# Neighbour list recomputed at step  4240
# List size:  4000
# Neighbour list recomputed at step  4310
# List size:  4000
# Neighbour list recomputed at step  4405
# List size:  4000
# Neighbour list recomputed at step  4449
# List size:  4000
# Neighbour list recomputed at step  4493
# List size:  4000
# Neighbour list recomputed at step  4610
# List size:  4000
# Neighbour list recomputed at step  4683
# List size:  4000
# Neighbour list recomputed at step  4734
# List size:  4000
# Neighbour list recomputed at step  4777
# List size:  4000
# Neighbour list recomputed at step  4820
# List size:  4000
# Neighbour list recomputed at step  4896
# List size:  4000
# Neighbour list recomputed at step  4988
# List size:  4000
# Neighbour list recomputed at step  5054
# List size:  4000
# Neighbour list recomputed at step  5110
# List size:  4000
# Neighbour list recomputed at step  5152
# List size:  4000
# Neighbour list recomputed at step  5248
# List size:  4000
# Neighbour list recomputed at step  5338
# List size:  4000
# Neighbour list recomputed at step  5459
# List size:  4000
# Neighbour list recomputed at step  5503
# List size:  4000
# Neighbour list recomputed at step  5618
# List size:  4000
# Neighbour list recomputed at step  5701
# List size:  4000
# Neighbour list recomputed at step  5731
# List size:  4000
# Neighbour list recomputed at step  5810
# List size:  4000
# Neighbour list recomputed at step  5908
# List size:  4000
# Neighbour list recomputed at step  6010
# List size:  4000
# Neighbour list recomputed at step  6123
# List size:  4000
# Neighbour list recomputed at step  6148
# List size:  4000
# Neighbour list recomputed at step  6201
# List size:  4000
# Neighbour list recomputed at step  6250
# List size:  4000
# Neighbour list recomputed at step  6295
# List size:  4000
# Neighbour list recomputed at step  6338
# List size:  4000
# Neighbour list recomputed at step  6392
# List size:  4000
# Neighbour list recomputed at step  6445
# List size:  4000
# Neighbour list recomputed at step  6479
# List size:  4000
# Neighbour list recomputed at step  6555
# List size:  4000
# Neighbour list recomputed at step  6594
# List size:  4000
# Neighbour list recomputed at step  6617
# List size:  4000
# Neighbour list recomputed at step  6678
# List size:  4000
# Neighbour list recomputed at step  6746
# List size:  4000
# Neighbour list recomputed at step  6817
# List size:  4000
# Neighbour list recomputed at step  6899
# List size:  4000
# Neighbour list recomputed at step  6995
# List size:  4000
# Neighbour list recomputed at step  7098
# List size:  4000
# Neighbour list recomputed at step  7170
# List size:  4000
# Neighbour list recomputed at step  7259
# List size:  4000
# Neighbour list recomputed at step  7339
# List size:  4000
# Neighbour list recomputed at step  7385
# List size:  4000
# Neighbour list recomputed at step  7452
# List size:  4000
# Neighbour list recomputed at step  7571
# List size:  4000
# Neighbour list recomputed at step  7662
# List size:  4000
# Neighbour list recomputed at step  7695
# List size:  4000
# Neighbour list recomputed at step  7736
# List size:  4000
# Neighbour list recomputed at step  7853
# List size:  4000
# Neighbour list recomputed at step  7891
# List size:  4000
# Neighbour list recomputed at step  7999
# List size:  4000
# 0.3843810558319092

# %%
# %%bash
# cat > in << EOF
# inputfile xyz/crystal1.xyz
# outputfile xyz/output.xyz
# temperature 0.722
# tstep 0.005
# friction 0.0
# forcecutoff 2.5
# listcutoff 3.0
# nstep 2000
# nconfig 10 xyz/trajectory.xyz
# nstat 10 xyz/energies.dat
# EOF
# python3 python/simplemd.py < in
# Out:
# Neighbour list recomputed at step  0
# List size:  4000
# Neighbour list recomputed at step  62
# List size:  4000
# Neighbour list recomputed at step  123
# List size:  4000
# Neighbour list recomputed at step  172
# List size:  4000
# Neighbour list recomputed at step  224
# List size:  4000
# Neighbour list recomputed at step  295
# List size:  4000
# Neighbour list recomputed at step  338
# List size:  4000
# Neighbour list recomputed at step  386
# List size:  4000
# Neighbour list recomputed at step  419
# List size:  4000
# Neighbour list recomputed at step  459
# List size:  4000
# Neighbour list recomputed at step  503
# List size:  4000
# Neighbour list recomputed at step  530
# List size:  4000
# Neighbour list recomputed at step  567
# List size:  4000
# Neighbour list recomputed at step  605
# List size:  4000
# Neighbour list recomputed at step  639
# List size:  4000
# Neighbour list recomputed at step  688
# List size:  4000
# Neighbour list recomputed at step  726
# List size:  4000
# Neighbour list recomputed at step  759
# List size:  4000
# Neighbour list recomputed at step  793
# List size:  4000
# Neighbour list recomputed at step  825
# List size:  4000
# Neighbour list recomputed at step  856
# List size:  4000
# Neighbour list recomputed at step  901
# List size:  4000
# Neighbour list recomputed at step  940
# List size:  4000
# Neighbour list recomputed at step  979
# List size:  4000
# Neighbour list recomputed at step  1018
# List size:  4000
# Neighbour list recomputed at step  1046
# List size:  4000
# Neighbour list recomputed at step  1077
# List size:  4000
# Neighbour list recomputed at step  1123
# List size:  4000
# Neighbour list recomputed at step  1154
# List size:  4000
# Neighbour list recomputed at step  1187
# List size:  4000
# Neighbour list recomputed at step  1219
# List size:  4000
# Neighbour list recomputed at step  1261
# List size:  4000
# Neighbour list recomputed at step  1301
# List size:  4000
# Neighbour list recomputed at step  1339
# List size:  4000
# Neighbour list recomputed at step  1378
# List size:  4000
# Neighbour list recomputed at step  1427
# List size:  4000
# Neighbour list recomputed at step  1459
# List size:  4000
# Neighbour list recomputed at step  1488
# List size:  4000
# Neighbour list recomputed at step  1539
# List size:  4000
# Neighbour list recomputed at step  1589
# List size:  4000
# Neighbour list recomputed at step  1644
# List size:  4000
# Neighbour list recomputed at step  1705
# List size:  4000
# Neighbour list recomputed at step  1744
# List size:  4000
# Neighbour list recomputed at step  1777
# List size:  4000
# Neighbour list recomputed at step  1811
# List size:  4000
# Neighbour list recomputed at step  1855
# List size:  4000
# Neighbour list recomputed at step  1883
# List size:  4000
# Neighbour list recomputed at step  1932
# List size:  4000
# Neighbour list recomputed at step  1978
# List size:  4000
# 0.11676836013793945

# %%
cat xyz/in
# Out:
# inputfile xyz/crystal1.xyz
# outputfile xyz/output.xyz
# temperature 0.1
# tstep 0.01
# friction 0.0
# forcecutoff 2.5
# listcutoff  3.0
# nstep 8000
# nconfig 10 xyz/trajectory.xyz
# nstat   10 xyz/energies.dat
