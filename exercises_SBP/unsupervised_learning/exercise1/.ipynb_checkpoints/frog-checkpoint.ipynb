# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def species2num(species):
    if (species == "Leptodactylidae"):
        return 0
    elif(species == "Hylidae"):
        return 1
    elif(species == "Dendrobatidae"):
        return 2
    elif(species == "Bufonidae"):
        return 3
    else:
        raise ValueError(species)

x = np.loadtxt('./Frogs_MFCCs.csv', skiprows=1, delimiter=',', usecols=tuple(np.arange(0, 22, 1)), unpack=True)
y = np.loadtxt('./Frogs_MFCCs.csv', skiprows=1, delimiter=',', usecols=22, converters={22: species2num}, encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_4539/2973062250.py in <module>
#      11         raise ValueError(species)
#      12
# ---> 13 x = np.loadtxt('./Frogs_MFCCs.csv', skiprows=1, delimiter=',', usecols=tuple(np.arange(0, 22, 1)), unpack=True)
#      14 y = np.loadtxt('./Frogs_MFCCs.csv', skiprows=1, delimiter=',', usecols=22, converters={22: species2num}, encoding="latin1")
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1063             fname = os_fspath(fname)
#    1064         if _is_string_like(fname):
# -> 1065             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1066             fencoding = getattr(fh, 'encoding', 'latin1')
#    1067             fh = iter(fh)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: ./Frogs_MFCCs.csv not found.

# %%
#centering
x = (x - np.mean(x, axis=1, keepdims=True)) / np.std(x, axis=1, keepdims=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4539/2449724646.py in <module>
#       1 #centering
# ----> 2 x = (x - np.mean(x, axis=1, keepdims=True)) / np.std(x, axis=1, keepdims=True)
#
# NameError: name 'x' is not defined

# %%
C = np.cov(x)

# %%
e, v = np.linalg.eigh(C)
e = e[::-1]
v = v[:, ::-1]

# %%
f = plt.figure(figsize=(10, 7))

plt.title("Spectrum", fontsize=20)
plt.ylabel("e", fontsize=15)
plt.xlabel("n", fontsize=15)

plt.yscale('log')
plt.plot(e, 'o')

plt.show()

# %%
y_1_PCA = np.sum(x*v[:, 0].reshape(-1, 1), axis=0)
y_2_PCA = np.sum(x*v[:, 1].reshape(-1, 1), axis=0)

# %%
f = plt.figure(figsize=(10, 7))

plt.title("Principal space projections", fontsize=20)

plt.xlabel("p2", fontsize=15)
plt.ylabel("p1", fontsize=15)

plt.plot(y_1_PCA[np.where(y==0)], y_2_PCA[np.where(y==0)], 'o', label='Leptodactylidae')
plt.plot(y_1_PCA[np.where(y==1)], y_2_PCA[np.where(y==1)], 'o', label='Hylidae')
plt.plot(y_1_PCA[np.where(y==2)], y_2_PCA[np.where(y==2)], 'o', label='Dendrobatidae')
plt.plot(y_1_PCA[np.where(y==3)], y_2_PCA[np.where(y==3)], 'o', label='Bufonidae')

plt.legend()

plt.show()
